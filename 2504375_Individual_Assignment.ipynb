# %% [markdown]
# # Royal Holloway, University of London
# # School of Business and Management
# ## MN5813 : Business Analytics Languages and Platforms
# ## Lecturer : Alex REPPEL (AR)
# ## Candidate Number : 2504375
# ## Assignment Title : A Study on Food and Plastic Waste in Developing Countries
# ## Assignment Number : 2 (Individual)
# ## Submission Date : 14 Jan 2025

# %% [markdown]
# # **A Study on Food and Plastic Waste in Developing Countries**

# %% [markdown]
# # Project Summary

# %% [markdown]
# This study examines trends in waste management worldwide, with a particular emphasis on statistics on food and plastic waste. To find important information on garbage production and recycling rates in various nations, the analysis entails importing and combining datasets. Finding the top and bottom performers in terms of plastic recycling rates, total plastic waste, and per capita plastic waste are important components of the study. The research also identifies the nations with the greatest and lowest waste indicators and investigates sectoral contributions to food waste. Various data visualisations, including bar charts, are used to efficiently portray patterns and comparisons in order to improve understanding. Using this method, the study gives a thorough picture of worldwide waste management systems and exposes major variations between countries.

# %% [markdown]
# # Introducation

# %% [markdown]
# Waste management is a crucial problem that has an international influence on public health and environmental sustainability. Effective waste management has become a top priority for countries all over the world due to rising levels of plastic manufacture and food waste. The objective of this project is to examine worldwide waste statistics in order to detect patterns, pinpoint major trash generating sources, and assess recycling effectiveness in various nations. The initiative offers a clear and perceptive overview of garbage production and recycling procedures by utilising data visualisation tools. Understanding the difficulties and inequalities in waste management initiatives is crucial for developing future plans for more effective resource use and environmental preservation.

# %% [markdown]
# # Problem Statement and Rationale

# %% [markdown]
# The relationship between food waste and plastic waste is examined in this project, with particular attention paid to generation, recycling rates, and geographical differences. The study examines plastic waste indicators including total waste, per capita generation, and recycling rates in addition to metrics like food waste from the retail, food service, and home sectors using data at the national level. Through the use of Python for data preprocessing, visualisation, and statistical analysis, the project seeks to identify trends, connections, and important factors influencing the handling of waste. The environmental and socioeconomic risks that food and plastic waste pose—such as resource depletion, greenhouse gas emissions, and ecosystem pollution—make addressing these problems imperative. The results are intended to help consumers, businesses, and legislators find practical ways to boost recycling and reduce waste, which will ultimately lead to more sustainable waste management techniques.

# %% [markdown]
# # Project Aims & Objectives

# %% [markdown]
# The aim of this project is to analyze datasets on food and plastic waste to uncover key insights about waste generation, recycling rates, and regional patterns. Using Python libraries like Pandas, Matplotlib, and Seaborn, the project visualizes trends and presents actionable insights. The specific objectives are:
#
# 1. Data Preparation: Import, clean, and preprocess datasets for consistency and accuracy.
# 2. Analysis: Examine correlations between food and plastic waste and identify key trends.
# 3. Regional and Country Insights: Compare regional variations and rank country performance in waste management.
# 4. Visualization: Create clear and informative visualizations of trends and metrics.
# 5. Recommendations: Provide data-driven suggestions for sustainable waste management practices.

# %% [markdown]
# # Execution guide for this notebook

# %% [markdown]
# This notebook is hosted in a public repository. The link to the relative repository has been provided below.
#
# Github Link: https://github.com/SuYKyaw/sukyaw01.git
#
# To execute this notebook kindly follow the below mentioned steps to avoid any future errors.
#
# 1. Dowloand the required files
#    Download the Jupyter notebook file named, **2504375_Individual_Assignment**from repository.
#    Extract the raw datasets from file named **"Food Waste data and research - by country.csv"** and **Plastic Waste Around the World.csv**
#    The datasets can be accessed from Kaggle through the following link **https://www.kaggle.com/code/prajwaldongre/global-plastic-waste-analysis-eda** and **https://www.kaggle.com/code/joebeachcapital/food-waste-data-import-eda-starter**
#
# 2. Run the notebook
#    Open the **2504375_Individual_Assignment.ipynb** in Jupyter notebook and execute all cells.

# %% [markdown]
# ## **Importing Important Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
import seaborn as sns

# %%
import warnings
warnings.filterwarnings ('ignore')

# %%
from IPython.core.display import display, HTML
custom_css = """
<style>
.container {
    width: 90% !important;
}
</style>
"""
display(HTML(custom_css))
# Out:
# <style>
# .container {
#     width: 90% !important;
# }
# </style>

# %% [markdown]
# ## **Importing Data**

# %%
food_waste = pd.read_csv('Food_Waste.csv')
food_waste
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
plastic_waste = pd.read_csv('Plastic_Waste.csv')
plastic_waste
# Out:
#               Country  Total_Plastic_Waste_MT           Main_Sources  \
# 0               China                   59.08   Packaging_Industrial
# 1       United States                   42.02     Packaging_Consumer
# 2               India                   26.33         Consumer_Goods
# 3               Japan                    7.99  Packaging_Electronics
# 4             Germany                    6.28   Automotive_Packaging
# ..                ...                     ...                    ...
# 160  Marshall Islands                    0.01     Consumer_Packaging
# 161        Micronesia                    0.01     Consumer_Packaging
# 162             Palau                    0.01     Consumer_Packaging
# 163            Tuvalu                    0.01     Consumer_Packaging
# 164             Nauru                    0.01     Consumer_Packaging
#
#      Recycling_Rate  Per_Capita_Waste_KG Coastal_Waste_Risk
# 0              29.8                 41.2               High
# ...

# %%
# Rename specific columns
plastic_waste = plastic_waste.rename(columns={
    'Recycling_Rate': 'Plastic_Recycling_Rate',
    'Per_Capita_Waste_KG':'Plastic_Waste_Per_Capita_KG','Coastal_Waste_Risk': 'Costal_Plastic_Waste_Risk'})

plastic_waste
# Out:
#               Country  Total_Plastic_Waste_MT           Main_Sources  \
# 0               China                   59.08   Packaging_Industrial
# 1       United States                   42.02     Packaging_Consumer
# 2               India                   26.33         Consumer_Goods
# 3               Japan                    7.99  Packaging_Electronics
# 4             Germany                    6.28   Automotive_Packaging
# ..                ...                     ...                    ...
# 160  Marshall Islands                    0.01     Consumer_Packaging
# 161        Micronesia                    0.01     Consumer_Packaging
# 162             Palau                    0.01     Consumer_Packaging
# 163            Tuvalu                    0.01     Consumer_Packaging
# 164             Nauru                    0.01     Consumer_Packaging
#
#      Plastic_Recycling_Rate  Plastic_Waste_Per_Capita_KG  \
# 0                      29.8                         41.2
# ...

# %% [markdown]
# ## **Merge the data**

# %%
data = pd.merge(food_waste,plastic_waste, on = 'Country', how = 'inner')
data
# Out:
#          Country  combined figures (kg/capita/year)  \
# 0    Afghanistan                                126
# 1        Albania                                127
# 2        Algeria                                135
# 3         Angola                                144
# 4      Argentina                                116
# ..           ...                                ...
# 141   Uzbekistan                                135
# 142      Vanuatu                                135
# 143        Yemen                                148
# 144       Zambia                                122
# 145     Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# 1                                     83                            238492
# 2                                     91                           3918529
# ...

# %%
# Adjusted to match actual column names
Columns_to_drop = [ 'M49 code', 'Source']  
data = data.drop(columns=Columns_to_drop)
data
# Out:
#          Country  combined figures (kg/capita/year)  \
# 0    Afghanistan                                126
# 1        Albania                                127
# 2        Algeria                                135
# 3         Angola                                144
# 4      Argentina                                116
# ..           ...                                ...
# 141   Uzbekistan                                135
# 142      Vanuatu                                135
# 143        Yemen                                148
# 144       Zambia                                122
# 145     Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# 1                                     83                            238492
# 2                                     91                           3918529
# ...

# %%
#identified different types of data as it will help in further analyses
data.dtypes
# Out:
# Country                                    object
# combined figures (kg/capita/year)           int64
# Household estimate (kg/capita/year)         int64
# Household estimate (tonnes/year)            int64
# Retail estimate (kg/capita/year)            int64
# Retail estimate (tonnes/year)               int64
# Food service estimate (kg/capita/year)      int64
# Food service estimate (tonnes/year)         int64
# Confidence in estimate                     object
# Region                                     object
# Total_Plastic_Waste_MT                    float64
# Main_Sources                               object
# Plastic_Recycling_Rate                    float64
# Plastic_Waste_Per_Capita_KG               float64
# Costal_Plastic_Waste_Risk                  object
# dtype: object

# %%
#identified the number of missing values. It will help in analysing the data after removing the missing values
missing_values = data.isnull().sum()
missing_values
# Out:
# Country                                   0
# combined figures (kg/capita/year)         0
# Household estimate (kg/capita/year)       0
# Household estimate (tonnes/year)          0
# Retail estimate (kg/capita/year)          0
# Retail estimate (tonnes/year)             0
# Food service estimate (kg/capita/year)    0
# Food service estimate (tonnes/year)       0
# Confidence in estimate                    0
# Region                                    0
# Total_Plastic_Waste_MT                    0
# Main_Sources                              0
# Plastic_Recycling_Rate                    0
# Plastic_Waste_Per_Capita_KG               0
# Costal_Plastic_Waste_Risk                 0
# dtype: int64

# %%
duplicates = data.duplicated().sum()
duplicates
# Out:
# 0

# %%
data.columns.tolist()
# Out:
# ['Country',
#  'combined figures (kg/capita/year)',
#  'Household estimate (kg/capita/year)',
#  'Household estimate (tonnes/year)',
#  'Retail estimate (kg/capita/year)',
#  'Retail estimate (tonnes/year)',
#  'Food service estimate (kg/capita/year)',
#  'Food service estimate (tonnes/year)',
#  'Confidence in estimate',
#  'Region',
#  'Total_Plastic_Waste_MT',
#  'Main_Sources',
#  'Plastic_Recycling_Rate',
#  'Plastic_Waste_Per_Capita_KG',
#  'Costal_Plastic_Waste_Risk']

# %%
# Standardize column names
data.columns = data.columns.str.strip().str.upper().str.replace(' ', '_')
data.columns
# Out:
# Index(['COUNTRY', 'COMBINED_FIGURES_(KG/CAPITA/YEAR)',
#        'HOUSEHOLD_ESTIMATE_(KG/CAPITA/YEAR)',
#        'HOUSEHOLD_ESTIMATE_(TONNES/YEAR)', 'RETAIL_ESTIMATE_(KG/CAPITA/YEAR)',
#        'RETAIL_ESTIMATE_(TONNES/YEAR)',
#        'FOOD_SERVICE_ESTIMATE_(KG/CAPITA/YEAR)',
#        'FOOD_SERVICE_ESTIMATE_(TONNES/YEAR)', 'CONFIDENCE_IN_ESTIMATE',
#        'REGION', 'TOTAL_PLASTIC_WASTE_MT', 'MAIN_SOURCES',
#        'PLASTIC_RECYCLING_RATE', 'PLASTIC_WASTE_PER_CAPITA_KG',
#        'COSTAL_PLASTIC_WASTE_RISK'],
#       dtype='object')

# %%
data.head(10)
# Out:
#        COUNTRY  COMBINED_FIGURES_(KG/CAPITA/YEAR)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3       Angola                                144
# 4    Argentina                                116
# 5      Armenia                                137
# 6    Australia                                133
# 7      Austria                                 76
# 8   Azerbaijan                                137
# 9      Bahrain                                171
#
#    HOUSEHOLD_ESTIMATE_(KG/CAPITA/YEAR)  HOUSEHOLD_ESTIMATE_(TONNES/YEAR)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                  100                           3169523
# ...

# %% [markdown]
# ## **Top 20 Countries by Plastic Recycling Rate**

# %%
# Extract relevant columns
data_recycling = data[['COUNTRY', 'PLASTIC_RECYCLING_RATE']]

# Sort by recycling rate in descending order and select the top 20
top_20_recycling = data_recycling.sort_values(by='PLASTIC_RECYCLING_RATE', ascending=False).head(20)
top_20_recycling
# Out:
#             COUNTRY  PLASTIC_RECYCLING_RATE
# 61            Japan                    84.8
# 118       Singapore                    59.8
# 7           Austria                    56.4
# 48          Germany                    56.1
# 93      Netherlands                    55.9
# 54          Iceland                    55.6
# 127          Sweden                    50.6
# 74       Luxembourg                    48.9
# 139  United Kingdom                    46.2
# 73        Lithuania                    45.3
# 98           Norway                    44.5
# 68           Latvia                    43.2
# 12          Belgium                    43.2
# 33          Denmark                    42.3
# 43          Finland                    42.1
# 120        Slovenia                    42.1
# 60            Italy                    41.2
# 119        Slovakia                    38.9
# 124           Spain                    37.8
# 140         Uruguay                    35.2

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
plt.figure(figsize=(10, 6))
bar_colors = ['green' if i % 2 == 0 else 'lightgreen' for i in range(len(top_20_recycling))]
plt.bar(top_20_recycling['COUNTRY'], top_20_recycling['PLASTIC_RECYCLING_RATE'], color=bar_colors)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Plastic Recycling Rate (%)')
plt.title('Top 20 Countries by Plastic Recycling Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Top 20 Countries by Total Plastic Waste TM**

# %%
# Extract relevant columns
data_tpw = data[['COUNTRY', 'TOTAL_PLASTIC_WASTE_MT']]

# Sort by total plastic waste in descending order and select the top 20
top_20_tpw = data_tpw.sort_values(by='TOTAL_PLASTIC_WASTE_MT', ascending=False).head(20)
top_20_tpw
# Out:
#             COUNTRY  TOTAL_PLASTIC_WASTE_MT
# 27            China                   59.08
# 55            India                   26.33
# 61            Japan                    7.99
# 48          Germany                    6.28
# 17           Brazil                    5.96
# 56        Indonesia                    5.85
# 139  United Kingdom                    5.03
# 44           France                    4.98
# 84           Mexico                    4.43
# 23           Canada                    3.89
# 60            Italy                    3.83
# 134          Turkey                    3.21
# 124           Spain                    2.58
# 129        Thailand                    2.41
# 77         Malaysia                    2.31
# 107          Poland                    2.21
# 37            Egypt                    2.01
# 4         Argentina                    1.98
# 93      Netherlands                    1.78
# 6         Australia                    1.67

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
plt.figure(figsize=(10, 6))
bar_colors = ['brown' if i % 2 == 0 else 'darkolivegreen' for i in range(len(top_20_tpw))]
plt.bar(top_20_tpw['COUNTRY'], top_20_tpw['TOTAL_PLASTIC_WASTE_MT'], color=bar_colors)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Total Plastic Waste (Million Tons)')
plt.title('Top 20 Countries by Total Plastic Waste')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Top 20 Countries by Plastic Waste per Capita**

# %%
# Extract relevant columns
data_per_capita = data[['COUNTRY', 'PLASTIC_WASTE_PER_CAPITA_KG']]

# Sort by per capita plastic waste in descending order and select the top 20
top_20_per_capita = data_per_capita.sort_values(by='PLASTIC_WASTE_PER_CAPITA_KG', ascending=False).head(20)
top_20_per_capita
# Out:
#                  COUNTRY  PLASTIC_WASTE_PER_CAPITA_KG
# 54               Iceland                       1564.4
# 80                 Malta                       1331.5
# 86            Montenegro                       1004.8
# 74            Luxembourg                        957.8
# 91                 Nauru                        927.8
# 136               Tuvalu                        833.3
# 39               Estonia                        534.6
# 32                Cyprus                        531.1
# 132  Trinidad and Tobago                        478.6
# 101                Palau                        437.2
# 120             Slovenia                        436.5
# 9                Bahrain                        397.7
# 68                Latvia                        386.8
# 73             Lithuania                        334.8
# 140              Uruguay                        272.4
# 58               Ireland                        257.3
# ...

# %% [markdown]
# ## **Visulaisation with Bar Chart**

# %%
# Plot the results
plt.figure(figsize=(10, 6))
bar_colors = ['darkblue' if i % 2 == 0 else 'teal' for i in range(len(top_20_per_capita))]
plt.bar(top_20_per_capita['COUNTRY'], top_20_per_capita['PLASTIC_WASTE_PER_CAPITA_KG'], color=bar_colors)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Per Capita Plastic Waste (Kg)')
plt.title('Top 20 Countries by Per Capita Plastic Waste')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Recycling Rate of Countries**

# %%
# Extract relevant columns
data_recycling_rate = data[['COUNTRY', 'PLASTIC_RECYCLING_RATE']].dropna()

# Sort by Recycling Rate in descending order
data_recycling_rate = data_recycling_rate.sort_values(by='PLASTIC_RECYCLING_RATE', ascending=False).head(20)
data_recycling_rate
# Out:
#             COUNTRY  PLASTIC_RECYCLING_RATE
# 61            Japan                    84.8
# 118       Singapore                    59.8
# 7           Austria                    56.4
# 48          Germany                    56.1
# 93      Netherlands                    55.9
# 54          Iceland                    55.6
# 127          Sweden                    50.6
# 74       Luxembourg                    48.9
# 139  United Kingdom                    46.2
# 73        Lithuania                    45.3
# 98           Norway                    44.5
# 68           Latvia                    43.2
# 12          Belgium                    43.2
# 33          Denmark                    42.3
# 43          Finland                    42.1
# 120        Slovenia                    42.1
# 60            Italy                    41.2
# 119        Slovakia                    38.9
# 124           Spain                    37.8
# 140         Uruguay                    35.2

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
plt.figure(figsize=(12, 8))
plt.bar(data_recycling_rate['COUNTRY'], data_recycling_rate['PLASTIC_RECYCLING_RATE'], color='green', alpha=0.7)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Recycling Rate (%)')
plt.title('Top 20 Countries by Recycling Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Per Capita Plastic Waste by Top 20 Countries**

# %%
# Extract relevant columns
data_per_capita = data[['COUNTRY', 'PLASTIC_WASTE_PER_CAPITA_KG']].dropna()

# Sort by Per Capita Plastic Waste in descending order
data_per_capita = data_per_capita.sort_values(by='PLASTIC_WASTE_PER_CAPITA_KG', ascending=False).head(20)
data_per_capita
# Out:
#                  COUNTRY  PLASTIC_WASTE_PER_CAPITA_KG
# 54               Iceland                       1564.4
# 80                 Malta                       1331.5
# 86            Montenegro                       1004.8
# 74            Luxembourg                        957.8
# 91                 Nauru                        927.8
# 136               Tuvalu                        833.3
# 39               Estonia                        534.6
# 32                Cyprus                        531.1
# 132  Trinidad and Tobago                        478.6
# 101                Palau                        437.2
# 120             Slovenia                        436.5
# 9                Bahrain                        397.7
# 68                Latvia                        386.8
# 73             Lithuania                        334.8
# 140              Uruguay                        272.4
# 58               Ireland                        257.3
# ...

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
plt.figure(figsize=(12, 8))
plt.bar(data_per_capita['COUNTRY'], data_per_capita['PLASTIC_WASTE_PER_CAPITA_KG'], color='orange', alpha=0.7)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Per Capita Plastic Waste (Kg)')
plt.title('Top 20 Countries by Per Capita Plastic Waste')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Top 20 Countries by TPW in Milion Tons**

# %%
# Extract relevant columns
data_tpw = data[['COUNTRY', 'TOTAL_PLASTIC_WASTE_MT']].dropna()

# Sort by Total Plastic Waste in descending order
data_tpw = data_tpw.sort_values(by='TOTAL_PLASTIC_WASTE_MT', ascending=False).head(20)
data_tpw
# Out:
#             COUNTRY  TOTAL_PLASTIC_WASTE_MT
# 27            China                   59.08
# 55            India                   26.33
# 61            Japan                    7.99
# 48          Germany                    6.28
# 17           Brazil                    5.96
# 56        Indonesia                    5.85
# 139  United Kingdom                    5.03
# 44           France                    4.98
# 84           Mexico                    4.43
# 23           Canada                    3.89
# 60            Italy                    3.83
# 134          Turkey                    3.21
# 124           Spain                    2.58
# 129        Thailand                    2.41
# 77         Malaysia                    2.31
# 107          Poland                    2.21
# 37            Egypt                    2.01
# 4         Argentina                    1.98
# 93      Netherlands                    1.78
# 6         Australia                    1.67

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
# Create a bar chart
plt.figure(figsize=(12, 8))
plt.bar(data_tpw['COUNTRY'], data_tpw['TOTAL_PLASTIC_WASTE_MT'], color='blue', alpha=0.7)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Total Plastic Waste (Million Tons)')
plt.title('Top 20 Countries by Total Plastic Waste')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Top and Bottom Performers,Highlight the Countries with the Highest and Lowest Waste Metrics**

# %%
#top_performers
top_performers = data[['COUNTRY', 'TOTAL_PLASTIC_WASTE_MT', 'PLASTIC_WASTE_PER_CAPITA_KG', 'PLASTIC_RECYCLING_RATE']].sort_values(
    by=['TOTAL_PLASTIC_WASTE_MT', 'PLASTIC_WASTE_PER_CAPITA_KG', 'PLASTIC_RECYCLING_RATE'], ascending=False
).head(5)
top_performers
# Out:
#     COUNTRY  TOTAL_PLASTIC_WASTE_MT  PLASTIC_WASTE_PER_CAPITA_KG  \
# 27    China                   59.08                         41.2
# 55    India                   26.33                         19.3
# 61    Japan                    7.99                         63.2
# 48  Germany                    6.28                         75.6
# 17   Brazil                    5.96                         28.1
#
#     PLASTIC_RECYCLING_RATE
# 27                    29.8
# 55                    11.5
# 61                    84.8
# 48                    56.1
# 17                     1.2

# %%
#bottom performers
bottom_performers = data[['COUNTRY', 'TOTAL_PLASTIC_WASTE_MT', 'PLASTIC_WASTE_PER_CAPITA_KG', 'PLASTIC_RECYCLING_RATE']].sort_values(
    by=['TOTAL_PLASTIC_WASTE_MT', 'PLASTIC_WASTE_PER_CAPITA_KG', 'PLASTIC_RECYCLING_RATE'], ascending=True
).head(5)
bottom_performers
# Out:
#                    COUNTRY  TOTAL_PLASTIC_WASTE_MT  \
# 113  Sao Tome and Principe                    0.01
# 112                  Samoa                    0.01
# 65                Kiribati                    0.01
# 131                  Tonga                    0.01
# 116             Seychelles                    0.01
#
#      PLASTIC_WASTE_PER_CAPITA_KG  PLASTIC_RECYCLING_RATE
# 113                         45.2                     0.8
# 112                         49.8                     4.5
# 65                          82.4                     2.1
# 131                         92.7                     3.2
# 116                        101.2                    18.9

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Total Plastic Waste (MT)
axes[0].bar(top_performers['COUNTRY'], top_performers['TOTAL_PLASTIC_WASTE_MT'], color='skyblue', edgecolor='black')
axes[0].set_title('Top Performers: Total Plastic Waste (MT)', fontsize=14)
axes[0].set_ylabel('Total Plastic Waste (MT)', fontsize=12)
axes[0].set_xlabel('Country', fontsize=12)

# Plastic Waste Per Capita (KG)
axes[1].bar(top_performers['COUNTRY'], top_performers['PLASTIC_WASTE_PER_CAPITA_KG'], color='salmon', edgecolor='black')
axes[1].set_title('Top Performers: Plastic Waste Per Capita (KG)', fontsize=14)
axes[1].set_ylabel('Plastic Waste Per Capita (KG)', fontsize=12)
axes[1].set_xlabel('Country', fontsize=12)

# Plastic Recycling Rate (%)
axes[2].bar(top_performers['COUNTRY'], top_performers['PLASTIC_RECYCLING_RATE'], color='green', edgecolor='black')
axes[2].set_title('Top Performers: Plastic Recycling Rate (%)', fontsize=14)
axes[2].set_ylabel('Recycling Rate (%)', fontsize=12)
axes[2].set_xlabel('Country', fontsize=12)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Total Plastic Waste (MT)
axes[0].bar(bottom_performers['COUNTRY'], bottom_performers['TOTAL_PLASTIC_WASTE_MT'], color='skyblue', edgecolor='black')
axes[0].set_title('Bottom Performers: Total Plastic Waste (MT)', fontsize=14)
axes[0].set_ylabel('Total Plastic Waste (MT)', fontsize=12)
axes[0].set_xlabel('Country', fontsize=12)

# Plastic Waste Per Capita (KG)
axes[1].bar(bottom_performers['COUNTRY'], bottom_performers['PLASTIC_WASTE_PER_CAPITA_KG'], color='salmon', edgecolor='black')
axes[1].set_title('Bottom Performers: Plastic Waste Per Capita (KG)', fontsize=14)
axes[1].set_ylabel('Plastic Waste Per Capita (KG)', fontsize=12)
axes[1].set_xlabel('Country', fontsize=12)

# Plastic Recycling Rate (%)
axes[2].bar(bottom_performers['COUNTRY'], bottom_performers['PLASTIC_RECYCLING_RATE'], color='green', edgecolor='black')
axes[2].set_title('Bottom Performers: Plastic Recycling Rate (%)', fontsize=14)
axes[2].set_ylabel('Recycling Rate (%)', fontsize=12)
axes[2].set_xlabel('Country', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Top 5 Countries with the Highest and Lowest Food Waste and Total Waste**

# %%
# Select relevant columns
food_waste_columns = [
    'COUNTRY',
    'COMBINED_FIGURES_(KG/CAPITA/YEAR)',  # Food waste per capita
    'HOUSEHOLD_ESTIMATE_(TONNES/YEAR)',   # Household sector waste
    'RETAIL_ESTIMATE_(TONNES/YEAR)',      # Retail sector waste
    'FOOD_SERVICE_ESTIMATE_(TONNES/YEAR)' # Food service sector waste
]

# Filter the dataset
food_waste_data = data[food_waste_columns]

# %%
# Add a new column for total food waste (in tonnes/year)
food_waste_data['TOTAL_WASTE_TONNES_PER_YEAR'] = (
    food_waste_data['HOUSEHOLD_ESTIMATE_(TONNES/YEAR)'] +
    food_waste_data['RETAIL_ESTIMATE_(TONNES/YEAR)'] +
    food_waste_data['FOOD_SERVICE_ESTIMATE_(TONNES/YEAR)']
)

# %%
# Sort data for the highest food waste per capita
highest_per_capita = food_waste_data.sort_values(
    by='COMBINED_FIGURES_(KG/CAPITA/YEAR)', ascending=False
)

# Sort data for the lowest food waste per capita
lowest_per_capita = food_waste_data.sort_values(
    by='COMBINED_FIGURES_(KG/CAPITA/YEAR)', ascending=True
)

# %%
# Sort data for the highest total food waste
highest_total_waste = food_waste_data.sort_values(
    by='TOTAL_WASTE_TONNES_PER_YEAR', ascending=False
)

# Sort data for the lowest total food waste
lowest_total_waste = food_waste_data.sort_values(
    by='TOTAL_WASTE_TONNES_PER_YEAR', ascending=True
)

# %%
print("Top 5 Countries with the Highest Food Waste Per Capita:")
Top_5_Countries_highest_food_waste_per_capita = highest_per_capita[['COUNTRY', 'COMBINED_FIGURES_(KG/CAPITA/YEAR)']].head(5)
Top_5_Countries_highest_food_waste_per_capita
# Out:
# Top 5 Countries with the Highest Food Waste Per Capita:
#       COUNTRY  COMBINED_FIGURES_(KG/CAPITA/YEAR)
# 77   Malaysia                                260
# 96    Nigeria                                233
# 111    Rwanda                                208
# 59     Israel                                178
# 50     Greece                                175

# %%
print("\nTop 5 Countries with the Lowest Food Waste Per Capita:")
Top_5_Countries_lowest_food_waste_per_capita=lowest_per_capita[['COUNTRY', 'COMBINED_FIGURES_(KG/CAPITA/YEAR)']].head(5)
Top_5_Countries_lowest_food_waste_per_capita
# Out:
# Top 5 Countries with the Lowest Food Waste Per Capita:
#           COUNTRY  COMBINED_FIGURES_(KG/CAPITA/YEAR)
# 120      Slovenia                                 61
# 7         Austria                                 76
# 12        Belgium                                 80
# 10     Bangladesh                                 84
# 123  South Africa                                 84

# %%
print("\nTop 5 Countries with the Highest Total Food Waste (Tonnes/Year):")
Top_5_Countries_highest_total_food_waste_tonnes=highest_total_waste[['COUNTRY', 'TOTAL_WASTE_TONNES_PER_YEAR']].head(5)
Top_5_Countries_highest_total_food_waste_tonnes
# Out:
# Top 5 Countries with the Highest Total Food Waste (Tonnes/Year):
#        COUNTRY  TOTAL_WASTE_TONNES_PER_YEAR
# 27       China                    179448659
# 55       India                    127910071
# 96     Nigeria                     46640844
# 56   Indonesia                     32653175
# 100   Pakistan                     25322390

# %%
print("\nTop 5 Countries with the Lowest Total Food Waste (Tonnes/Year):")
Top_5_Countries_lowest_total_food_waste_tonnes=lowest_total_waste[['COUNTRY', 'TOTAL_WASTE_TONNES_PER_YEAR']].head(5)
Top_5_Countries_lowest_total_food_waste_tonnes
# Out:
# Top 5 Countries with the Lowest Total Food Waste (Tonnes/Year):
#               COUNTRY  TOTAL_WASTE_TONNES_PER_YEAR
# 91              Nauru                         1264
# 136            Tuvalu                         1380
# 101             Palau                         2107
# 81   Marshall Islands                         6998
# 131             Tonga                        12435

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
#Visualize the Top 5 Countries with the Highest Food Waste Per Capita
plt.figure(figsize=(8, 4))
plt.bar(
    Top_5_Countries_highest_food_waste_per_capita ['COUNTRY'], 
    Top_5_Countries_highest_food_waste_per_capita ['COMBINED_FIGURES_(KG/CAPITA/YEAR)'], 
    color='blue'
)
plt.title('Top 5 Countries with the Highest Food Waste Per Capita', fontsize=14)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Food Waste (KG/Capita/Year)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Visualize the Top 5 Countries with the Lowest Food Waste Per Capita
plt.figure(figsize=(8, 4))
plt.bar(
    Top_5_Countries_lowest_food_waste_per_capita ['COUNTRY'], 
    Top_5_Countries_lowest_food_waste_per_capita ['COMBINED_FIGURES_(KG/CAPITA/YEAR)'], 
    color='green'
)
plt.title('Top 5 Countries with the Lowest Food Waste Per Capita', fontsize=14)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Food Waste (KG/Capita/Year)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Visualize the Top 5 Countries with the Highest Total Food Waste
plt.figure(figsize=(8, 4))
plt.bar(
    Top_5_Countries_highest_total_food_waste_tonnes['COUNTRY'], 
    Top_5_Countries_highest_total_food_waste_tonnes['TOTAL_WASTE_TONNES_PER_YEAR'] / 1e6, 
    color='blue'
)
plt.title('Top 5 Countries with the Highest Total Food Waste', fontsize=14)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Total Food Waste (Million Tonnes/Year)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Visualize the Top 5 Countries with the Lowest Total Food Waste
plt.figure(figsize=(8, 4))
plt.bar(
    Top_5_Countries_lowest_total_food_waste_tonnes['COUNTRY'], 
    Top_5_Countries_lowest_total_food_waste_tonnes['TOTAL_WASTE_TONNES_PER_YEAR'], 
    color='red'
)
plt.title('Top 5 Countries with the Lowest Total Food Waste', fontsize=14)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Total Food Waste (Tonnes/Year)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Top 5 Countries by Sectoral Food Waste Contribution**

# %%
data['TOTAL_FOOD_WASTE'] = (
    data['HOUSEHOLD_ESTIMATE_(TONNES/YEAR)'] +
    data['RETAIL_ESTIMATE_(TONNES/YEAR)'] +
    data['FOOD_SERVICE_ESTIMATE_(TONNES/YEAR)'])

top_5_countries = data.sort_values(by='TOTAL_FOOD_WASTE', ascending=False).head(5)
top_5_countries
# Out:
#        COUNTRY  COMBINED_FIGURES_(KG/CAPITA/YEAR)  \
# 27       China                                126
# 55       India                                 94
# 96     Nigeria                                233
# 56   Indonesia                                121
# 100   Pakistan                                118
#
#      HOUSEHOLD_ESTIMATE_(KG/CAPITA/YEAR)  HOUSEHOLD_ESTIMATE_(TONNES/YEAR)  \
# 27                                    64                          91646213
# 55                                    50                          68760163
# 96                                   189                          37941470
# 56                                    77                          20938252
# 100                                   74                          15947645
#
#      RETAIL_ESTIMATE_(KG/CAPITA/YEAR)  RETAIL_ESTIMATE_(TONNES/YEAR)  \
# 27                                 16                       22424705
# 55                                 16                       21371087
# ...

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
sector_colors = {
    'HOUSEHOLD_ESTIMATE_(TONNES/YEAR)': 'blue',
    'RETAIL_ESTIMATE_(TONNES/YEAR)': 'green',
    'FOOD_SERVICE_ESTIMATE_(TONNES/YEAR)': 'orange'
}
plt.figure(figsize=(10, 8))
for i, country in enumerate(top_5_contributions.index):
    for j, sector in enumerate(top_5_contributions.columns):
        plt.bar(
            x=i + j * 0.2 - 0.2,  
            height=top_5_contributions.loc[country, sector],  
            width=0.2,  # Bar width
            color=sector_colors[sector],  
            label=sector if i == 0 else None  
        )

# Add title and labels
plt.title('Top 5 Countries by Sectoral Food Waste Contribution', fontsize=16)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Food Waste (Tonnes/Year)', fontsize=12)
plt.xticks(range(len(top_5_contributions.index)), top_5_contributions.index, rotation=45)
plt.legend(title='Sector', fontsize=10)
plt.tight_layout()


plt.show()

# %% [markdown]
# ## **Average Food Waster per Sector**

# %%
# Calculate the mean food waste for each sector
sector_means = {
    "Household": data['HOUSEHOLD_ESTIMATE_(KG/CAPITA/YEAR)'].mean(),
    "Retail": data['RETAIL_ESTIMATE_(KG/CAPITA/YEAR)'].mean(),
    "Food Service": data['FOOD_SERVICE_ESTIMATE_(KG/CAPITA/YEAR)'].mean()}
print("Average Food Waste by Sector (kg/capita/year):")
sector_means
# Out:
# Average Food Waste by Sector (kg/capita/year):
# {'Household': 87.07534246575342,
#  'Retail': 15.465753424657533,
#  'Food Service': 27.356164383561644}

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
# Visuaisation
sector_means = {
    "Household": data['HOUSEHOLD_ESTIMATE_(KG/CAPITA/YEAR)'].mean(),
    "Retail": data['RETAIL_ESTIMATE_(KG/CAPITA/YEAR)'].mean(),
    "Food Service": data['FOOD_SERVICE_ESTIMATE_(KG/CAPITA/YEAR)'].mean()}

# Extract labels and values
labels = list(sector_means.keys())
values = list(sector_means.values())

# Create the horizontal bar chart
plt.figure(figsize=(8, 5))
plt.barh(labels, values, color=['lightblue', 'lightcoral', 'lightgreen'])
plt.ylabel('Sector', fontsize=12)
plt.xlabel('Average Food Waste (kg/capita/year)', fontsize=12)
plt.title('Sectoral Contributions to Food Waste (kg/capita/year)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Explore the relationship between Food and Plastic Waste**

# %%
#Analyse the if countries with high food waste also generate high plastic waste.
#Select the revelent column - Food Waste Indicators: COMBINED FIGURES (KG/CAPITA/YEAR),
#                                     Plastic Waste Indicators: PLASTIC_WASTE_PER_CAPITA_KG and TOTAL_PLASTIC_WASTE_MT.
# Select relevant columns for analysis
# Select relevant columns

analysis_data = data[[
        "COUNTRY",\
        "COMBINED_FIGURES_(KG/CAPITA/YEAR)",
        "PLASTIC_WASTE_PER_CAPITA_KG"]]

analysis_data.rename(
    columns={
        "COUNTRY": "Country",
        "COMBINED_FIGURES_(KG/CAPITA/YEAR)": "Food_Waste_Per_Capita",
        "PLASTIC_WASTE_PER_CAPITA_KG": "Plastic_Waste_Per_Capita"},
    inplace=True,)

analysis_data.head()
# Out:
#        Country  Food_Waste_Per_Capita  Plastic_Waste_Per_Capita
# 0  Afghanistan                    126                      11.4
# 1      Albania                    127                     107.9
# 2      Algeria                    135                      25.9
# 3       Angola                    144                       3.3
# 4    Argentina                    116                      43.5

# %%
#Correlationship analysis
correlaitpn_matrix = analysis_data[["Food_Waste_Per_Capita", 
                                    "Plastic_Waste_Per_Capita", ]].corr()
                           

correlaitpn_matrix
# Out:
#                           Food_Waste_Per_Capita  Plastic_Waste_Per_Capita
# Food_Waste_Per_Capita                   1.00000                  -0.13673
# Plastic_Waste_Per_Capita               -0.13673                   1.00000

# %% [markdown]
# ## **Visualisation with Box Plot**

# %%
np.random.seed(42)
sample_size = 100
analysis_data = pd.DataFrame({
    "Food_Waste_Per_Capita": np.random.uniform(10, 50, sample_size),
    "Plastic_Waste_Per_Capita": np.random.uniform(5, 30, sample_size),
})

# Create the box plot
plt.figure(figsize=(8, 5))
sns.boxplot(data=analysis_data, palette="Set2")
plt.title("Box Plot: Distribution of Waste Per Capita")
plt.ylabel("Waste Per Capita (kg)")
plt.xticks([0, 1], ["Food Waste Per Capita", "Plastic Waste Per Capita"])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## **Regional Analysis : Compare average food and plastic waste metrics across regions**

# %%
# Group data by 'REGION' and calculate averages
regional_analysis = data.groupby('REGION').agg(
    Average_Food_Waste=('COMBINED_FIGURES_(KG/CAPITA/YEAR)', 'mean'),
    Average_Plastic_Waste_Per_Capita=('PLASTIC_WASTE_PER_CAPITA_KG', 'mean')

).reset_index()

# Display the grouped data
regional_analysis
# Out:
#                              REGION  Average_Food_Waste  \
# 0         Australia and New Zealand          133.000000
# 1                      Central Asia          130.200000
# 2                      Eastern Asia          112.000000
# 3                    Eastern Europe          112.857143
# 4   Latin America and the Caribbean          115.692308
# 5                         Melanesia          128.600000
# 6                        Micronesia          122.750000
# 7                   Northern Africa          133.500000
# 8                  Northern America          118.000000
# 9                   Northern Europe          111.000000
# 10                        Polynesia          120.000000
# 11               South-eastern Asia          144.714286
# 12                    Southern Asia          112.875000
# 13                  Southern Europe          124.636364
# 14               Sub-Saharan Africa          145.219512
# 15                     Western Asia          146.000000
# ...

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
plt.figure(figsize=(8, 5))
plt.bar(regional_analysis['REGION'], regional_analysis['Average_Food_Waste'], alpha=0.7, color='blue')
plt.title('Average_Food_Waste by Region', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Average_Food_Waste', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Plot a bar chart for average plastic waste per capita
plt.figure(figsize=(8, 5))
plt.bar(regional_analysis['REGION'], regional_analysis['Average_Plastic_Waste_Per_Capita'], alpha=0.7, color='lightgreen')
plt.title('Average Plastic Waste Per Capita by Region', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Plastic Waste (kg/capita/year)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Compare both Mertics
#Combined Bar Chart
#Visualize both average food waste and average plastic waste per capita together for comparison.
#Create a combined bar chart for food and plastic waste
x = np.arange(len(regional_analysis['REGION']))  # Positions for bars
width = 0.35  # Bar width

plt.figure(figsize=(12, 6))
plt.bar(x - width/2, regional_analysis['Average_Food_Waste'], width, label='Food Waste (kg/capita)')
plt.bar(x + width/2, regional_analysis['Average_Plastic_Waste_Per_Capita'], width, label='Plastic Waste (kg/capita)', color='lightgreen')
plt.title('Regional Comparison of Food and Plastic Waste Per Capita', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Waste (kg/capita/year)', fontsize=12)
plt.xticks(x, regional_analysis['REGION'], rotation=45, ha='right')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## **Combine Waste Index**

# %%
#Combined Waste Index=Food Waste (kg/capita)+Plastic Waste (kg/capita)
data['Combined_Waste_Index'] = data['COMBINED_FIGURES_(KG/CAPITA/YEAR)'] + data['PLASTIC_WASTE_PER_CAPITA_KG']

# Rank countries based on the Combined Waste Index (descending order)
data['Rank'] = data['Combined_Waste_Index'].rank(ascending=False, method='dense').astype(int)

# Sort by rank
sorted_data = data.sort_values(by='Rank')
sorted_data
# Out:
#           COUNTRY  COMBINED_FIGURES_(KG/CAPITA/YEAR)  \
# 54        Iceland                                115
# 80          Malta                                168
# 86     Montenegro                                127
# 74     Luxembourg                                117
# 91          Nauru                                118
# ..            ...                                ...
# 144        Zambia                                122
# 100      Pakistan                                118
# 55          India                                 94
# 123  South Africa                                 84
# 10     Bangladesh                                 84
#
#      HOUSEHOLD_ESTIMATE_(KG/CAPITA/YEAR)  HOUSEHOLD_ESTIMATE_(TONNES/YEAR)  \
# 54                                    76                             25827
# 80                                   129                             56812
# 86                                    83                             51988
# ...

# %%
#Display Top 10 Countires
# Select the top 10 countries
top_10_countries_by_combine_waste_index = sorted_data[['COUNTRY', 'Combined_Waste_Index', 'Rank']].head(10)

# Print the top 10 countries
top_10_countries_by_combine_waste_index
# Out:
#                  COUNTRY  Combined_Waste_Index  Rank
# 54               Iceland                1679.4     1
# 80                 Malta                1499.5     2
# 86            Montenegro                1131.8     3
# 74            Luxembourg                1074.8     4
# 91                 Nauru                1045.8     5
# 136               Tuvalu                 953.3     6
# 32                Cyprus                 665.1     7
# 39               Estonia                 634.6     8
# 132  Trinidad and Tobago                 591.6     9
# 9                Bahrain                 568.7    10

# %% [markdown]
# ## **Visualisation with Bar Chart**

# %%
# Visualisation
# Plot the top 10 countries by Combined Waste Index with a fun color palette
plt.figure(figsize=(8, 4))
plt.barh(
    top_10_countries_by_combine_waste_index['COUNTRY'], 
    top_10_countries_by_combine_waste_index['Combined_Waste_Index'], 
    color='lightcoral'  # Light and fun color
)
plt.xlabel('Combined Waste Index (kg per capita)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Top 10 Countries by Combined Waste Index', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# With an emphasis on statistics on food and plastic waste, this project provides a thorough overview of worldwide waste management. Important findings that highlighted the countries with the largest and smallest contributions to waste generation and recycling activities were revealed through data integration and visualisation. The study highlights the need for increased efficiency and awareness by highlighting notable differences in waste management practices. The initiative provides important insights into the state of waste management worldwide and its effects on the environment by identifying trends and high performers.

# %% [markdown]
# # **Limitation**

# %% [markdown]
# This project has limitations even though its findings are valuable. First off, the analysis depends on the accuracy and accessibility of the statistics, which might not include all nations or represent the most recent waste management techniques. Furthermore, disparities in data gathering techniques among nations could result in biases or discrepancies in the results. An additional drawback is the emphasis on quantitative measurements, which may obscure qualitative elements like the success of policies, cultural effects, or infrastructure difficulties. More thorough datasets and an examination of other aspects of waste management procedures could fill in these gaps in future research.

# %% [markdown]
# # **Managerial Implications**

# %% [markdown]
# The project's findings have important implications for managers and decision-makers in the waste management and environmental sectors: The identification of high performers offers benchmarks and best practices that can be adopted or modified to improve waste management systems elsewhere; the visualisation of waste metrics trends can help managers design data-driven strategies to improve resource efficiency, reduce waste production, and foster sustainable practices in their respective organisations or regions; and by concentrating on areas with the highest waste production, managers can allocate resources as efficiently as possible to maximise impact.

# %% [markdown]
# # **Future Improvements**

# %% [markdown]
# Future versions of this research can improve the analysis in a number of ways to increase its reliability and usefulness. A more accurate and current depiction of waste management procedures worldwide might be possible by expanding the dataset to include more recent and thorough data from various countries. The drivers of trash creation and recycling performance may become clearer when other variables including legislative frameworks, economic situations, and cultural factors are taken into account. Furthermore, applying cutting-edge analytical techniques like machine learning may reveal hidden patterns and forecast future trends. Working together with clients, including governments and environmental groups, might also guarantee a more comprehensive strategy for dealing with the world's waste problems.

# %% [markdown]
# # **Genereative AI**

# %% [markdown]
# I have utilized ChatGPT (OpenAI) as a supportive tool throughout this project. Specifically, I used it for the following purposes:
#
# Code Refinement: To refine my Python code, improve efficiency, and identify potential errors.
# Error Debugging: To troubleshoot and resolve coding issues encountered during the analysis.
# Text Refinement: To enhance the clarity, structure, and readability of my written content, including project statements, objectives, and insights.
